# %%
import pandas as pd
import numpy as np
import os
# %matplotlib inline

# %% [markdown]
#  ### Dataset Loading for visualization

# %%
data_path = '../data/raw/owid-covid-data.csv'

# %%
df_country_info = pd.read_csv(data_path, sep=',')
#df_country_info.head()

# %%
#df_country_info.columns

# %%
df_GER = df_country_info[df_country_info['location'] == 'Germany']
df_GER.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 65883      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 65884      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 65885      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 65886      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 65887      DEU    Europe  Germany  2020-01-31          5.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 65883                 NaN           NaN         NaN                  NaN  ...
# 65884                 NaN           NaN         NaN                  NaN  ...
# 65885                 NaN           NaN         NaN                  NaN  ...
# 65886                 NaN           NaN         NaN                  NaN  ...
# 65887                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
#df_GER = df_GER.reset_index(drop=True)

# %% [markdown]
# ### Total COVID Cases (Germany)

# %%
import plotly.express as px

# %%
fig = px.line(df_GER, x="date", y="total_cases", title='COVID Cases')
fig.show()
# Out:
# <div>                            <div id="2bf7b241-93ec-42bf-9ef9-3882b1378df8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bf7b241-93ec-42bf-9ef9-3882b1378df8")) {                    Plotly.newPlot(                        "2bf7b241-93ec-42bf-9ef9-3882b1378df8",                        [{"hovertemplate":"date=%{x}<br>total_cases=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","
# ...

# %%
df_GER['total_cases']/df_GER['population']
# Out:
# 65883    1.191888e-08
# 65884    4.767554e-08
# 65885    4.767554e-08
# 65886    4.767554e-08
# 65887    5.959442e-08
#              ...
# 66753    3.229609e-01
# 66754    3.232960e-01
# 66755    3.242527e-01
# 66756    3.242527e-01
# 66757    3.243354e-01
# Length: 875, dtype: float64

# %%
#df_country_info['location'].unique()

# %% [markdown]
# ### Total COVID Cases of Multiple Countries

# %%
b_GER = df_country_info['location'] == 'Germany'
b_US = df_country_info['location'] == 'United States'
b_INDIA = df_country_info['location'] == 'India'
b_ITALY = df_country_info['location'] == 'Italy'

# %%
b_all = b_GER|b_US|b_INDIA|b_ITALY

# %%
df_my_list = df_country_info[b_all]
df_my_list = df_my_list.reset_index(drop=True)
#df_my_list.head(5)

# %%
fig = px.line(df_my_list, x="date", y="total_cases", color='location', title='COVID Cases')
fig.show()
# Out:
# <div>                            <div id="9318cde1-6bf5-48e9-b2ac-da5e2e777ea8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9318cde1-6bf5-48e9-b2ac-da5e2e777ea8")) {                    Plotly.newPlot(                        "9318cde1-6bf5-48e9-b2ac-da5e2e777ea8",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>total_cases=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13"
# ...

# %% [markdown]
# ### The Relative Cases Overtime of Covid Infectors (absolute Covid cases/population size)

# %%
df_my_list['total_cases_norm'] = df_my_list['total_cases']/df_my_list['population']
#df_my_list[['date', 'total_cases', 'location','total_cases_norm', 'population']]

# %%
fig = px.line(df_my_list, x="date", y="total_cases_norm", color='location', title='Relative COVID Cases')
fig.show()
# Out:
# <div>                            <div id="71270578-4636-4d1e-88ad-7c30997c42e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71270578-4636-4d1e-88ad-7c30997c42e5")) {                    Plotly.newPlot(                        "71270578-4636-4d1e-88ad-7c30997c42e5",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>total_cases_norm=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-0
# ...

# %% [markdown]
# ### Save the Graph as an Image

# %%
fig.write_image("../images/Relative_COVID_Cases.png")

# %% [markdown]
# ### The vaccination rate (percentage of the population) over time

# %%
df_my_list['vaccination_rate'] = (df_my_list['people_fully_vaccinated']/df_my_list['population']) * 100
df_my_list = df_my_list.loc[(df_my_list["date"] >= "2020-12-13")]

# %%
#df_my_list[['date', 'total_cases', 'location','vaccination_rate', 'people_fully_vaccinated', 'population']]

# %%
fig = px.line(df_my_list, x='date', y="vaccination_rate", color='location', title='Vaccination Rate')
fig.show()
# Out:
# <div>                            <div id="819752cd-16c9-48ac-95a6-0fd0c162c784" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("819752cd-16c9-48ac-95a6-0fd0c162c784")) {                    Plotly.newPlot(                        "819752cd-16c9-48ac-95a6-0fd0c162c784",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>vaccination_rate=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-12-13","2020-12-14","2020-12-15","2020-12-16","2020-12-17","2020-12-18","2020-12-19","2020-12-20","2020-12-21","2020-12-22","2020-12-23","2020-12-24","2020-12-25","2020-12-26","2020-12-27","2020-12-28","2020-12-29","2020-1
# ...

# %%
fig.write_image("../images/Vaccination_Rate.png")
